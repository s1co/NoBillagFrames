# %% [markdown]
# # Notebook für einfache Test und Blick in die Daten

# %%
# Importiere Bibliotheken
import os
import re
import numpy as np
import pandas as pd

# %%
# Daten einlesen
data_raw = pd.read_pickle('data_modified/tweets.pkl')

# %% [markdown]
# ### Tests

# %%
# Tweets pro Tag
print(data_raw['2017-10-01':'2018-03-04'].groupby(data_raw['2017-10-01':'2018-03-04'].index.date).count())
# Out:
#             User  Tweet  Retweet  RT_from  Orig_Tweet  Tweet_Participants  \
# 2017-10-01    66     66       66       28          66                  66
# 2017-10-02   163    163      163       72         163                 163
# 2017-10-03   117    117      117       45         117                 117
# 2017-10-04    72     72       72       36          72                  72
# 2017-10-05   132    132      132       67         132                 132
# 2017-10-06    82     82       82       28          82                  82
# 2017-10-07    91     91       91       29          91                  91
# 2017-10-08   138    138      138       49         138                 138
# 2017-10-09   147    147      147       59         147                 147
# 2017-10-10   179    179      179       77         179                 179
# 2017-10-11   216    216      216      100         216                 216
# 2017-10-12   208    208      208      123         208                 208
# ...

# %%
# Tweets gesamt
print(data_raw['2017-10-01':'2018-03-04'].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 99511 entries, 2017-10-31 09:59:00 to 2017-10-31 09:55:00
# Data columns (total 11 columns):
# User                  99511 non-null object
# Tweet                 99511 non-null object
# Retweet               99511 non-null bool
# RT_from               46131 non-null object
# Orig_Tweet            99511 non-null bool
# Tweet_Participants    99511 non-null object
# Reply                 99511 non-null bool
# Text                  99511 non-null object
# Tags                  99511 non-null object
# Lang                  99511 non-null object
# Link                  99511 non-null object
# dtypes: bool(3), object(8)
# memory usage: 7.1+ MB
# None

# %%
# Anzahl der Twitter-Account
data_raw['2017-10-01':'2018-03-04']['User'].nunique()
# Out:
# 12091
